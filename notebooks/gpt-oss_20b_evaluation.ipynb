# %% [markdown]
# # Evaluating the result for Gemma3-12B

# %%
import pandas as pd

# %%
def print_results_from_log_df(df: pd.DataFrame) -> None:
    dcpm_cols = df.filter(like='DCPMI')

    df['Max DCPMI Name'] = dcpm_cols.idxmax(axis=1)
    df['Max DCPMI Value'] = dcpm_cols.max(axis=1)

    df.dropna(inplace=True)

    for column in df['Max DCPMI Name'].unique():
        print('-'*100)
        print('Cards:', column.split()[0])
        print('Number of times picked:', (df['Max DCPMI Name'] == column).sum())

# %% [markdown]
# ## Load the results

# %%
model_name = 'gpt-oss_20b'

logs_dfs_dict = {
    'Control': pd.read_csv(f'../logs/{model_name}_control_wason_study_results.csv'),
    'Anchoring': pd.read_csv(f'../logs/{model_name}_anchoring_wason_study_results.csv'),
    'Framing': pd.read_csv(f'../logs/{model_name}_framing_wason_study_results.csv'),
    'Position': pd.read_csv(f'../logs/{model_name}_position_wason_study_results.csv'),
}

# %%
for experiment_name, logs_df in logs_dfs_dict.items():
    print('='*100)
    print('EXPERIMENT:', experiment_name)
    print_results_from_log_df(logs_df)
# Out:
# ====================================================================================================
# EXPERIMENT: Control
# ----------------------------------------------------------------------------------------------------
# Cards: A
# Number of times picked: 2
# ----------------------------------------------------------------------------------------------------
# Cards: B
# Number of times picked: 15
# ----------------------------------------------------------------------------------------------------
# Cards: D
# Number of times picked: 70
# ----------------------------------------------------------------------------------------------------
# Cards: C
# Number of times picked: 11
# ----------------------------------------------------------------------------------------------------
# Cards: AD
# Number of times picked: 1
# ====================================================================================================
# EXPERIMENT: Anchoring
# ----------------------------------------------------------------------------------------------------
# Cards: D
# Number of times picked: 53
# ----------------------------------------------------------------------------------------------------
# Cards: A
# Number of times picked: 9
# ----------------------------------------------------------------------------------------------------
# Cards: C
# Number of times picked: 29
# ----------------------------------------------------------------------------------------------------
# Cards: B
# Number of times picked: 8
# ====================================================================================================
# EXPERIMENT: Framing
# ----------------------------------------------------------------------------------------------------
# Cards: A
# Number of times picked: 96
# ----------------------------------------------------------------------------------------------------
# Cards: AD
# Number of times picked: 2
# ----------------------------------------------------------------------------------------------------
# Cards: D
# Number of times picked: 1
# ====================================================================================================
# EXPERIMENT: Position
# ----------------------------------------------------------------------------------------------------
# Cards: C
# Number of times picked: 82
# ----------------------------------------------------------------------------------------------------
# Cards: A
# Number of times picked: 1
# ----------------------------------------------------------------------------------------------------
# Cards: D
# Number of times picked: 14
# ----------------------------------------------------------------------------------------------------
# Cards: B
# Number of times picked: 1
# ----------------------------------------------------------------------------------------------------
# Cards: CD
# Number of times picked: 1
# C:\Users\Miro\AppData\Local\Temp\ipykernel_14120\3707539104.py:4: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df['Max DCPMI Name'] = dcpm_cols.idxmax(axis=1)
# C:\Users\Miro\AppData\Local\Temp\ipykernel_14120\3707539104.py:4: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df['Max DCPMI Name'] = dcpm_cols.idxmax(axis=1)
# C:\Users\Miro\AppData\Local\Temp\ipykernel_14120\3707539104.py:4: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df['Max DCPMI Name'] = dcpm_cols.idxmax(axis=1)
# C:\Users\Miro\AppData\Local\Temp\ipykernel_14120\3707539104.py:4: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df['Max DCPMI Name'] = dcpm_cols.idxmax(axis=1)
