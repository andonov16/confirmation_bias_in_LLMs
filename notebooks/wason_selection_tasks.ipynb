# %% [markdown]
# # Wason Selection Tasks

# %%
import pandas as pd
import yaml

with open('../config/wason_selection_tasks_config.yaml', 'r') as f:
    walson_config = yaml.safe_load(f)

# %% [markdown]
# ## Load the tasks

# %%
wason_tasks_df = pd.read_csv('../data/wason_selection_tasks.csv')
wason_tasks_df
# Out:
#                                                  Rule                   P  \
# 0         If an animal is a dog, then it is a mammal.                 Dog
# 1   If a card has a vowel on one side, then it has...                   A
# 2   If a person is a mother, then they have at lea...              Mother
# 3            If a switch is on, then the light is on.           Switch on
# 4        If a paper is wet, then it will tear easily.           Wet paper
# 5   If an object is transparent, then light passes...         Transparent
# 6         If a bird is a penguin, then it cannot fly.             Penguin
# 7      If water boils, then its temperature is 100°C.       Water boiling
# 8              If a metal is heated, then it expands.        Heated metal
# 9   If an athlete trains daily, then performance i...        Trains daily
# 10  If a student studies, then they will pass the ...             Studies
# 11  If you press the red button, then the alarm so...    Press red button
# ...

# %% [markdown]
# ## ===
